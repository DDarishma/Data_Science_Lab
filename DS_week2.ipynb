# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'Age': [25, 30, np.nan, 40, 35],
    'Department': ['HR', 'Finance', np.nan, 'IT', 'HR']
})

df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Department'].fillna(df['Department'].mode()[0], inplace=True)

print(df)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5         HR
# 3  40.0         IT
# 4  35.0         HR
# /tmp/ipykernel_3149/1923069103.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# /tmp/ipykernel_3149/1923069103.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Department'].fillna(df['Department'].mode()[0], inplace=True)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age': [25,30,np.nan,40,35],
    'Department' : ['HR','Finance','Finance',np.nan,'IT']
})
df_ffill = df.copy()
df_ffill.fillna(method='ffill',inplace=True)
print(df_ffill)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0    Finance
# 4  35.0         IT
# /tmp/ipykernel_3149/1789641957.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill.fillna(method='ffill',inplace=True)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age':[25,30,np.nan,40,35],
    'Department': ['HR','Finance','Finance',np.nan,'IT']
})
df_drop_rows=df.dropna()
print("After dropping rows:\n",df_drop_rows)
# Out:
# After dropping rows:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 4  35.0         IT

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'Age':[25,30,np.nan,40,35],
    'Department': ['HR','Finance','Finance',np.nan,'IT']
})
df_drop_cols=df.dropna(axis=1)
print("After dropping columns:\n",df_drop_cols)
# Out:
# After dropping columns:
#  Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
import pandas as pd

df = pd.DataFrame({
    'ID': [1, 2, 2, 3, 4, 4],
    'Name': ['Alison', 'Bob', 'Bob', 'Charlie', 'David', 'David'],
    'Age': [25, 30, 30, 35, 40, 40]
})

print("Original Data:\n", df)

df_exact = df.drop_duplicates()

print("\nAfter Exact Match Removal:\n", df_exact)
# Out:
# Original Data:
#     ID     Name  Age
# 0   1   Alison   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After Exact Match Removal:
#     ID     Name  Age
# 0   1   Alison   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
df_subset_id = df.drop_duplicates(subset=['ID'])
print("\nAfter Subset-Based Removal (ID):\n", df_subset_id)

df_subset_name = df.drop_duplicates(subset=['Name'])
print("\nAfter Subset-Based Removal (Name):\n", df_subset_name)
# Out:
# After Subset-Based Removal (ID):
#     ID     Name  Age
# 0   1   Alison   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
#
# After Subset-Based Removal (Name):
#     ID     Name  Age
# 0   1   Alison   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
import pandas as pd


df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025', '2025.01.05']
})


df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)
# Out:
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'BOB', 'charlie', 'DAVID']
})


df['Name_lower'] = df['Name'].str.lower()


df['Name_upper'] = df['Name'].str.upper()

print(df)
# Out:
#       Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      BOB        bob        BOB
# 2  charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID
